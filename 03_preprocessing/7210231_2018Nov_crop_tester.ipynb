# %% [markdown]
# ### Batch_Crop
# * 한림대학교 딥러닝이해및응용(7210231) 과목 자료입니다
# * Hallym Univ.
# * Deeplearning
# * 2018/11/20

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from dd_nnutil_hallym_batchcrop import *

# %%
folder1 = './data'

# %%
batch_crop(folder1, to_rotate  = False, resize_ratio = 0.17)
# Out:
# 0
# ./data\0\mountain.jpg
# ./data\0\snow.jpg
# ./data\0\mountain.jpg
# ./data\0\snow.jpg
# 1
# 2
# 3
# 4

# %% [markdown]
# idx = 12
# image_class = 5
# #for i in range( 0, 100, 5):
#     fig, ax = plt.subplots(figsize=(20, 10), dpi=80)
#     img, img_crop = load_image_compare(folder1, image_class, idx =i)
#     plt.subplot(1,2,1)
#     plt.imshow(img)
#     plt.subplot(1,2,2)
#     plt.imshow(img_crop)

# %%
idx = 12
image_class = 5
fig, ax = plt.subplots(figsize=(20, 10), dpi=80)
img, img_crop = load_image_compare(folder1, image_class, idx =idx)
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(img_crop)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-1a3fc72412dd> in <module>
#       2 image_class = 5
#       3 fig, ax = plt.subplots(figsize=(20, 10), dpi=80)
# ----> 4 img, img_crop = load_image_compare(folder1, image_class, idx =idx)
#       5 plt.subplot(1,2,1)
#       6 plt.imshow(img)
#
# ~\710231\03_preprocessing\dd_nnutil_hallym_batchcrop.py in load_image_compare(dirpath, img_class, idx)
#      70 def load_image_compare(dirpath, img_class, idx = 0):
#      71     img_folder_path = os.path.join(dirpath, str(img_class))
# ---> 72     img_name = os.listdir(img_folder_path)[idx]
#      73     img = Image.open(os.path.join(img_folder_path, img_name))
#      74
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: './data\\5'

# %%
img_crop.sizea
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6d00f41dfc94> in <module>
# ----> 1 img_crop.sizea
#
# NameError: name 'img_crop' is not defined
